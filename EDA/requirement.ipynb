# %% [markdown]
# ### 1. Data Source & Dataset Size
# *   **Source:** State that the dataset is **Fashion-MNIST**, a dataset of Zalando's article images, intended as a direct drop-in replacement for the original MNIST dataset. (Mention your specific CSV source if it came from Kaggle).
# *   **Quantity:**
#     *   Total Samples: $70,000$
#     *   Training Set: $60,000$ images (which you split into $50,000$ for training and $10,000$ for validation).
#     *   Test Set: $10,000$ images.
# *   **Dimensions:** Each sample is a $28 \times 28$ grayscale image ($784$ total pixels).
#
# ### 2. Meaning of Each Class
# Include a table to map the integers to human-readable names. This is mandatory for your **Qualitative Analysis** later.
#
# | Label | Description | Label | Description |
# | :--- | :--- | :--- | :--- |
# | 0 | T-shirt/top | 5 | Sandal |
# | 1 | Trouser | 6 | Shirt |
# | 2 | Pullover | 7 | Sneaker |
# | 3 | Dress | 8 | Bag |
# | 4 | Coat | 9 | Ankle boot |
#
# ### 3. Visualizations (The "Evidence")
# You need to include at least two types of plots:
#
# *   **A) Sample Grid:** A plot showing at least one example image from each of the 10 categories.
#     *   *Insight for report:* Mention that images are centered and occupy a similar portion of the frame, which simplifies preprocessing.
# *   **B) Class Distribution (Bar Chart):** A chart showing the count of images per class.
#     *   *Insight for report:* State that the dataset is **perfectly balanced** (exactly $6,000$ images per class in the original train set). This means you don't need to worry about "Class Imbalance" issues.
#
# ### 4. Pixel Intensity Analysis (Optional but recommended)
# Show a histogram of pixel values (ranging from 0 to 255).
# *   *Observation:* You will notice most pixels are 0 (black background).
# *   *Justification:* This justifies why you used **StandardScaler**—to center the non-zero values and handle the sparsity of the background.
#
# ### 5. Preprocessing Pipeline Justification (Requirement 4.1)
# The PDF specifically asks you to **"justify each preprocessing step."** You should write:
#
# 1.  **Reshaping:** "Images were flattened from $28 \times 28$ matrices into $784$-feature vectors to be compatible with traditional machine learning algorithms like KNN and Logistic Regression."
# 2.  **Normalization ($/255$):** "Pixel values were scaled to the $[0, 1]$ range to prevent large integer values from causing numerical instability during calculation."
# 3.  **Standardization (StandardScaler):** "Features were centered around a mean of $0$ with a standard deviation of $1$. This is essential for **KNN**, as it ensures all pixels contribute equally to the distance calculation, and for **Logistic Regression**, as it helps the solver converge faster."
#
# ---
#
# ### Suggested EDA Report Structure (Drafting Outline)
# *   **3. Dataset Description**
#     *   3.1 Source and Size
#     *   3.2 Class Definitions and Examples (Include your grid plot here)
#     *   3.3 Class Balance (Include your bar chart here)
# *   **4.1 Data Preprocessing Pipeline**
#     *   4.1.1 Step-by-Step Pipeline (Flattening $\rightarrow$ Scaling $\rightarrow$ Splitting)
#     *   4.1.2 Justification of Scaling (Explain why you used `StandardScaler` for KNN/Logistic)
#
# **Thiện's Tip:** In the **Qualitative Analysis** part of your final results, refer back to the EDA. For example: *"As shown in our EDA sample grid, Coats and Pullovers share very similar shapes. This explains why our best model occasionally confused these two classes in the Confusion Matrix."* (This connects your EDA to your Results, which teachers love).
